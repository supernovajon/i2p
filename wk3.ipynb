# %%
cities = ["Bristol", "London", "Manchester", "Edinburgh", "Belfast", "York"]
print("The position of Manchester in the list is: " + str(cities [2] ))
print(cities[2 + 2])
print(cities[-2])
temperatures = [15.6, 16.5, 13.4, 14.0, 15.2, 14.8]
city="Manchester"
print("the average temp in " + city + " is " + str(temperatures[cities.index("Manchester")]) + " degrees")
city="Belfast"
print("the average temp in " + city + " is " + str(temperatures[cities.index("Belfast")]) + " degrees")
def avg_tmp(city,temperatures):
    print(f"The average temperature in {city} is {temperatures[cities.index(city)]}")
city="Edinburgh"
avg_tmp(city,temperatures)
# Out:
# The position of Manchester in the list is: Manchester
# Belfast
# Belfast
# the average temp in Manchester is 13.4 degrees
# the average temp in Belfast is 15.2 degrees
# The average temperature in Edinburgh is 14.0
# The average temperature in Bristol is 15.6
# The average temperature in London is 16.5
# The average temperature in Manchester is 13.4
# The average temperature in Edinburgh is 14.0
# The average temperature in Belfast is 15.2
# The average temperature in York is 14.8

# %%
for c in cities:
    avg_tmp(c,temperatures)
# Out:
# The average temperature in Bristol is 15.6
# The average temperature in London is 16.5
# The average temperature in Manchester is 13.4
# The average temperature in Edinburgh is 14.0
# The average temperature in Belfast is 15.2
# The average temperature in York is 14.8
